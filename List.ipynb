// %%
// 1. Define the Node Structure
class ListNode {
    int val;
    ListNode next;
    ListNode(int val) { this.val = val; }
}

// 2. Write an Algorithm (Example: Reverse a Linked List)
public ListNode reverseList(ListNode head) {
    ListNode prev = null;
    ListNode current = head;
    while (current != null) {
        ListNode nextNode = current.next;
        current.next = prev;
        prev = current;
        current = nextNode;
    }
    return prev;
}

// 3. Helper Method to Print the List
public void printList(ListNode head) {
    ListNode temp = head;
    while (temp != null) {
        System.out.print(temp.val + " -> ");
        temp = temp.next;
    }
    System.out.println("null");
}

// 4. Test the Implementation
ListNode head = new ListNode(1);
head.next = new ListNode(2);
head.next.next = new ListNode(3);

System.out.print("Original List: ");
printList(head);

ListNode reversed = reverseList(head);
System.out.print("Reversed List: ");
printList(reversed);
// Out:
// Original List: 1 -> 2 -> 3 -> null
// Reversed List: 3 -> 2 -> 1 -> null

// %% [markdown]
// ## Mermaid

// %% [markdown]
// ```mermaid
// graph LR
//     Head((Head)) --> A[Val: 1]
//     A --> B[Val: 2]
//     B --> C[Val: 3]
//     C --> D[/Null/]
//
//     style Head fill:#f9f,stroke:#333,stroke-width:2px
//     style D fill:#ccc,stroke:#333
// ```

// %% [markdown]
// <iframe src="https://visualgo.net" width="100%" height="500px" style="border: 1px solid #ccc; border-radius: 8px;"></iframe>

// %% [markdown]
// [![](https://mermaid.ink/img/pako:eNpFkDtvgzAQgP8KuimRCMEvYjxUSsjQoe3QoUNDBrd2AxJg5BipLeK_15hEveEe3710N8KnURoEXKzsq-jptewiL49aqtVq1ut1tNk8RPvTm2xEhM5Lfh_gYYH4Bg8BFgskN1gEeDxtX4am2Z4h9ptqBcLZQcfQatvKOYRxLi_BVbrVJQjvfsir98pu8j297N6Nae9t1gyXCsSXbK4-GnolnT7W0t_wX6I7pW1hhs6BQCiMADHCNwiMUUI4xzhlNKec-OQPiAwljFDKONvt8jznbIrhN-xEScpIxtM0wzin3pAYtKqdsc_L78ILpz8pg15-?type=png)](https://mermaid.live/edit#pako:eNo9kDtvgzAQgP8KuimRCME2JsZDpYQMHdoOHTo0ZHBrNyBhjBwstUX89xqT9IZ7fPfS3QifRirgcLGir6On16qLvDwqIVerWa_X0WbzEO1Pb6LlETov-X2AhwXiGzwEWC6Q3GAZ4PG0fXFtuz1D7Dc1EvhgnYpBK6vFHMI4l1cw1EqrCrh3P8TVe1U3-Z5edO_G6HubNe5SA_8S7dVHrpdiUMdG-Bv0P7Wqk8qWxnUD8DyMAD7CN3CMUUIYwzilWZExgmL48SUooSTLKKO7XVEUjE4x_IadKEkpyVma5hgXmTckBiWbwdjn5XfhhdMfNHxenQ)
