# %% [markdown]
# # Calling cell in this notebook from another

# %% [markdown]
# <a id="link-note"></a>
# ### 1. Used to print a line
# Lined through linkToNote, click on cell to see below id
#
# \<a id="link-note"></a>

# %% [markdown]
# <a id="button-note"></a>
# ### 1. Used to print a line
# Lined through buttonToNote, click on cell to see below id
#
# \<a id="button-note"></a>

# %% [markdown]
# <a id="print-note"></a>
#
# This Cell id is print-Note

# %% [markdown]
# ### Sliding Window Concept

# %% [markdown]
# <div id="array-bounds-warning" style="scroll-margin-top: 100px;"></div>
# array-bounds-warning

# %% [markdown]
# <div id="linear-time-proof" style="scroll-margin-top: 100px;"></div>
# linear-time-proof

# %% [markdown]
# <div id="important-note" style="scroll-margin-top: 100px;"></div>
# important-note
#
# A char variable cannot be empty

# %% [markdown]
# # Programmatic Example of Saga Pattern in Java

# %% [markdown]
# <a id="my-target-anchor"></a>
# This is my target anchor. (Can i say the cell has id of *my-target-anchor ?*)
