// %% [markdown]
// # Links to check

// %% [markdown]
// https://scaleengineer.com/dsa/problems/two-sum

// %% [markdown]
// https://scaleengineer.com/dsa/problems/next-permutation
//
// https://www.dsavisualizer.in/visualizer/searching/linearsearch
//
// # Paid
//
//
// https://www.codechef.com/roadmap/data-structures-and-algorithms
//
// https://www.canva.com/en_in/pricing/
//
// https://skillflow.dev/submission-summary/6a2e3c7db13fe136b180e708?latest=true
