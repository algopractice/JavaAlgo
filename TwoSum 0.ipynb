// %% [markdown]
// # 1. Two Sum (LeetCode #1) — Easy
//
// ## 📌 Problem Description
// Given an array of integers `nums` and an integer `target`, return indices of the two numbers such that they add up to `target`. Each input has exactly one solution, and you may not use the same element twice.
//
// ---
//
// ## 💡 Algorithmic Strategy (HashMap Lookups)
//
// ### ⚙️ How It Works:
// Instead of checking every pair ($O(N^2)$), we scan the array **once**. For each element, we check if its matching **complement** ($target - current$) is already stored in our Map.
// * If **found**: We instantly return the saved index and the current index.
// * If **not found**: We add the current number and its index to the map and move forward.

// %% [markdown]
//                   [ START ]
//                       │
//                       ▼
//             [ Initialize HashMap ]
//                       │
//                       ▼
//          ┌───►[ Get Next Element ]
//          │            │
//          │            ▼
//          │    Calculate Complement
//          │    (Target - Current)
//          │            │
//          │            ▼
//          │    /─────────────────┐
//          │   ⟨  Is Complement   ⟩
//          │    ⟨   in HashMap?   ⟩
//          │    └─────────────────┘
//          │       /           \
//          │      / No          \ Yes
//          │     ▼               ▼
//          │ [Store Value & index]  [ RETURN INDICES ]
//          │     │                       (Success)
//          │     ▼                           │
//          └─{Has Next?}                     ▼
//                │ No                     [ END ]
//                ▼
//        [ RETURN EMPTY ARRAY ]
//             (No Solution)

// %% [markdown]
// [![](https://mermaid.ink/img/pako:eNpNksFum0AQhl9lNCdbwgiDsQGprRLj2K6SHtpeWvBhZTZmVdhFy6LEQbx7x4Adc1lm9H8z_-xsi0eVcYzwpFmVw-84lUDfwyT5ZZg2hynMZl_hMdlLYQQrxAeHHavzF1ZFIJuSzsNAPPbCdfKsVAUm16o55cC0Zmd4EyYHITP-DmJUr3t13O7rUcPLypxBaSgu_KuQos559q0b5DHJ4Q-ve2ozSX5y02g5Qn2BCH4oqFXRGKHkYXqHUf5CPSUprllxbApmOBxVWRW85NLAF6BBT9zA7DJQnZBFHF0-9eS2jRW1HqYlUhom5F2Fq8ntvckdtRtdSv5G05vk0I41bOo2-eSnFgjobk23d6b3VOUhy8AoKD9v3K4aMxm9Eju9ofthB0Ow64Pvk2Qjs-uFbIYcWrRukWFkdMMtLLku2SXE9iJL0eRkLMWIfjOm_6WYyo6Yism_SpVXrF8xRq-sqClqqowuNhaMHlJ5y2pOa9dr1UiDkef2NTBq8R0j153bXhC4ruMvwkXgzS08Y7Sc2763WPiBv1qFYRj4nYUffdO57fjeMnAcz3ed1TIMlxbyTBilX4YX3D_k7j9AGtw5?type=png)](https://mermaid.live/edit#pako:eNpNkk2PmzAQhv_KyCcikQgjEoilttoN2SRVt4e2lxZysII3WAUbGaPdLOK_7_CRbHyBGb3PzDset-SkM0EYORte5fAnThXgeXCS35Ybe5zBfP4VHpODklbyQr4L2PM6f-YVA9WU-D2OxOMg3CQ_tK7A5kY35xy4MfwCr9LmIFUm3kBO6s2gjttDPWlEWdkLaANFz79IJetcZN-6UR6jHP6KeqC2TvJL2MaoCRoKMPipodZFY6VWx9kdhvmeekpSsuHFqSm4FXDSZVWIUigLXwAHPQsL836gOkGLZHL5NJC7NtbYepwWSWW5VHcVriZ39yb32G5yqcQrTm-TYzvVWGA355OfuSChuzXd3Zk-YJWHLAOrofy88UXVWGfyiuzshh7GHYzBfgi-O8lWZdcL2Y454uK6ZUaYNY1wSSlMyfuQtL0sJTZHYylh-Jtx8z8lqeqQqbj6p3V5xYYVE_bCixqjpsrwYmPJ8SGVt6wRuHaz0Y2yhNFwqEFYS94I82m0CKlPAw9P4K2WvksuhM2XwcLzomC9iuh6HYZ0GXQueR_60kVAPZ-Gq8APo4DSCAuKTFptnsdHPLzl7gO_a9yo)

// %% [markdown]
// ## 🧪 Method Templates
//
// ### 🏎️ 1. Optimal Solution (HashMap Approach)

// %%
public int[] twoSum(int[] nums, int target) {
    java.util.Map<Integer, Integer> map = new java.util.HashMap<>();
    for (int i = 0; i < nums.length; i++) {
        int complement = target - nums[i];
        if (map.containsKey(complement)) {
            return new int[] { map.get(complement), i };
        }
        map.put(nums[i], i);
    }
    return new int[] {};
}

// %%
int[] result = twoSum(new int[]{1, 2, 3, 5}, 6);
System.out.println(java.util.Arrays.toString(result));
// Out:
// [0, 3]

// %% [markdown]
// ### 🎯 2. Alternative Solution (Two-Pointer Sort Approach)
// *Note: This approach works only if the array is pre-sorted or if we track original indices.*
// Logic: If sorted, move left pointer up if sum is low, move right down if sum is high

// %%
int left = 0, right = nums.length - 1;
while (left < right) {
    int currentSum = nums[left] + nums[right];
    if (currentSum == target) return new int[]{left, right};
    else if (currentSum < target) left++;
    else right--;
}
// Out:
// |   int left = 0, right = nums.length - 1;
// cannot find symbol
//   symbol:   variable nums

// %% [markdown]
// ---
//
// ## 📉 Complexity Comparison
//
// | Strategy | Time Complexity | Space Complexity | Best Used For |
// | :--- | :--- | :--- | :--- |
// | **HashMap Lookups** | $O(N)$ | $O(N)$ | Unsorted arrays, optimal execution speed |
// | **Two Pointers** | $O(N \log N)$ | $O(1)$ | Memory-constrained or pre-sorted inputs |
